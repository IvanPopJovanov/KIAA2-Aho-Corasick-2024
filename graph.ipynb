# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
df = pd.read_csv("stats1.csv")

# %%
df = df.drop(["abstract/bytes","matrix/bytes", "tree/bytes", "kmp/bytes"], axis=1)

# %%
df.describe()
# Out:
#           text length  abstract/ms    matrix/ms      tree/ms       kmp/ms
# count     1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean    500500.000000   200.975371     4.484494   175.223866   209.001661
# std     288819.436096    96.802085     2.373379    79.450932   112.721738
# min       1000.000000    33.788000     0.390000    38.236000    13.292000
# 25%     250750.000000   116.990000     2.462750   106.731000   111.323500
# 50%     500500.000000   200.206000     4.440500   174.504500   209.139500
# 75%     750250.000000   286.777250     6.546000   245.173250   307.094250
# max    1000000.000000   383.515000     9.395000   342.553000   418.343000

# %%
plt.plot(df["text length"], df["matrix/ms"], label="Matrica")
plt.plot(df["text length"], df["tree/ms"], label="Pretraživačko Stablo")
plt.plot(df["text length"], df["kmp/ms"], label="KMP")
plt.legend()
plt.savefig("plot1.png")
plt.show()

# %%
df = pd.read_csv("stats2.csv")

# %%
df = df.drop(["abstract/bytes","matrix/bytes", "tree/bytes", "kmp/bytes"], axis=1)

# %%
df.describe()
# Out:
#          keywords  abstract/ms   matrix/ms     tree/ms      kmp/ms
# count  100.000000    100.00000  100.000000  100.000000  100.000000
# mean    50.500000    334.40192    8.592500  278.619790  205.613800
# std     29.011492     30.87367    1.626913   29.048207  119.244962
# min      1.000000    275.04900    4.044000  220.706000    4.253000
# 25%     25.750000    309.62025    8.067750  256.911000  103.694750
# 50%     50.500000    337.88000    9.048500  281.613000  203.692000
# 75%     75.250000    362.13625    9.796500  304.581250  308.439750
# max    100.000000    383.42000   10.570000  327.900000  406.347000

# %%
plt.plot(df["keywords"], df["matrix/ms"], label="Matrica")
plt.plot(df["keywords"], df["tree/ms"], label="Pretraživačko Stablo")
plt.plot(df["keywords"], df["kmp/ms"], label="KMP")
plt.legend()
plt.savefig("plot2.png")
plt.show()
