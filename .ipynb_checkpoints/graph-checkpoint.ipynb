# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
df = pd.read_csv("stats1.csv")

# %%
df = df.drop(["abstract/bytes","matrix/bytes", "tree/bytes", "kmp/bytes"], axis=1)

# %%
df.describe()
# Out:
#           text length  abstract/ms    matrix/ms      tree/ms      kmp/ms
# count     1000.000000   1000.00000  1000.000000  1000.000000  1000.00000
# mean    500500.000000    204.33742     4.514330   180.284473   200.64067
# std     288819.436096     97.89698     2.385507    82.474135   106.54188
# min       1000.000000     35.42200     0.393000    37.742000    15.31000
# 25%     250750.000000    121.46600     2.496500   109.888750   109.56500
# 50%     500500.000000    202.91700     4.500000   179.567500   200.16700
# 75%     750250.000000    286.85925     6.581000   249.837500   292.74675
# max    1000000.000000    374.90900     9.081000   331.637000   383.85000

# %%
plt.plot(df["text length"], df["matrix/ms"], label="Matrica")
plt.plot(df["text length"], df["tree/ms"], label="Pretraživačko Stablo")
plt.plot(df["text length"], df["kmp/ms"], label="KMP")
plt.legend()
plt.savefig("plot1.png")
plt.show()

# %%
df = pd.read_csv("stats2.csv")

# %%
df = df.drop(["abstract/bytes","matrix/bytes", "tree/bytes", "kmp/bytes"], axis=1)

# %%
df.describe()
# Out:
#          keywords  abstract/ms   matrix/ms     tree/ms      kmp/ms
# count  100.000000   100.000000  100.000000  100.000000  100.000000
# mean    50.500000   332.152280    8.895420  280.208420  208.132600
# std     29.011492    31.381293    1.657613   28.933887  121.868339
# min      1.000000   271.063000    4.061000  222.927000    4.229000
# 25%     25.750000   307.462000    8.388750  256.760000  103.800500
# 50%     50.500000   333.637500    9.567000  283.544000  203.560000
# 75%     75.250000   362.331500   10.051750  306.331750  322.636000
# max    100.000000   387.667000   10.649000  329.405000  411.638000

# %%
plt.plot(df["keywords"], df["matrix/ms"], label="Matrica")
plt.plot(df["keywords"], df["tree/ms"], label="Pretraživačko Stablo")
plt.plot(df["keywords"], df["kmp/ms"], label="KMP")
plt.legend()
plt.savefig("plot2.png")
plt.show()
